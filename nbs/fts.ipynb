# %%
from pgsql_search.database import PostgreSQLDatabase

with PostgreSQLDatabase("my_database") as db:
    res = db.full_text_search(
        query="man in a yellow shirt", 
        table_name="image_metadata", 
        search_column="caption", 
        num_results=10,
        interactive_output=True
    )
# Out:
# 2024-12-18 23:50:55.003 | INFO     | pgsql_search.database:connect:116 - Connected to database
# 2024-12-18 23:50:55.006 | INFO     | pgsql_search.database:setup_pgvector_extension:133 - pgvector extension initialized
# <table id="itables_60dd78b5_9492_4f15_b803_74692a228db6" class="display" data-quarto-disable-processing="true" style="width:100%;margin:auto">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#       <th>image_filepath</th>
#       <th>caption</th>
#       <th>user_query</th>
#       <th>parsed_query</th>
#       <th>search_rank</th>
#       <th>image</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_60dd78b5_9492_4f15_b803_74692a228db6:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[1547, "<a href=\"../data/images/176288.jpg\" target=\"_blank\">../data/images/176288.jpg</a>", "A young man in yellow shirt blocking a soccer ball.", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.05, "<img src=\"../data/images/176288.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"], [15713, "<a href=\"../data/images/515751.jpg\" target=\"_blank\">../data/images/515751.jpg</a>", "A man in a yellow shirt skateboarding outside.", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.033333, "<img src=\"../data/images/515751.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"], [15919, "<a href=\"../data/images/291696.jpg\" target=\"_blank\">../data/images/291696.jpg</a>", "A man in a yellow shirt jumping over three people.", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.033333, "<img src=\"../data/images/291696.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"], [20894, "<a href=\"../data/images/358389.jpg\" target=\"_blank\">../data/images/358389.jpg</a>", "A man in a yellow shirt wearing glasses.", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.033333, "<img src=\"../data/images/358389.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"], [17749, "<a href=\"../data/images/224222.jpg\" target=\"_blank\">../data/images/224222.jpg</a>", "three men out on the ocean water two of the men watching their friend surf waves blue oceans water a man wearing a green shirt and yellow shorts", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.02, "<img src=\"../data/images/224222.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"], [29518, "<a href=\"../data/images/479848.jpg\" target=\"_blank\">../data/images/479848.jpg</a>", "A man in brown shirt holding a yellow condiment bottle at a hotdog stand.", "man in a yellow shirt", "'man' & 'yellow' & 'shirt'", 0.02, "<img src=\"../data/images/479848.jpg\" style=\"max-height: 150px; max-width: 300px; object-fit: contain;\"/>"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# 2024-12-18 23:50:55.369 | INFO     | pgsql_search.database:disconnect:125 - Disconnected from database

# %%
res
