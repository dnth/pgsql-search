# %%
from pgsql_search.database import PostgreSQLDatabase

with PostgreSQLDatabase("my_database") as db:
    res = db.full_text_search("baby", "image_metadata", "caption", num_results=10)
# Out:
# 2024-12-18 17:21:49.646 | INFO     | pgsql_search.database:connect:86 - Connected to database
# 2024-12-18 17:21:49.649 | INFO     | pgsql_search.database:setup_pgvector_extension:103 - pgvector extension initialized
# 2024-12-18 17:21:49.652 | INFO     | pgsql_search.database:full_text_search:272 - Found 1 results for query: baby
# 2024-12-18 17:21:49.653 | INFO     | pgsql_search.database:disconnect:95 - Disconnected from database

# %%
res
# Out:
#    id                image_filepath  \
# 0   2  ../data/images100/477389.jpg
#
#                                              caption   query  search_rank
# 0  The baby elephant is walking with a small obje...  'babi'          0.1

# %%
import PIL.Image

PIL.Image.open(res.iloc[0]["image_filepath"])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x504>
